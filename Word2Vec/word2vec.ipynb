# %%
"""Basic word2vec example."""

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'

# %%
def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urllib.request.urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception(
        'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words."""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

vocabulary = read_data(filename)
print('Data size', len(vocabulary))
# Out:
# Data size 17005207

# %%
count = [['UNK', -1]]
count.extend(collections.Counter(vocabulary).most_common(50000 - 1))
count
# Out:
# [['UNK', -1],
#  ('the', 1061396),
#  ('of', 593677),
#  ('and', 416629),
#  ('one', 411764),
#  ('in', 372201),
#  ('a', 325873),
#  ('to', 316376),
#  ('zero', 264975),
#  ('nine', 250430),
#  ('two', 192644),
#  ('is', 183153),
#  ('as', 131815),
#  ('eight', 125285),
#  ('for', 118445),
#  ('s', 116710),
#  ('five', 115789),
#  ('three', 114775),
#  ('was', 112807),
#  ('by', 111831),
#  ('that', 109510),
#  ('four', 108182),
#  ('six', 102145),
#  ('seven', 99683),
#  ('with', 95603),
#  ('on', 91250),
#  ('are', 76527),
#  ('it', 73334),
#  ('from', 72871),
#  ('or', 68945),
#  ('his', 62603),
#  ('an', 61925),
#  ('be', 61281),
#  ('this', 58832),
#  ('which', 54788),
#  ('at', 54576),
#  ('he', 53573),
#  ('also', 44358),
#  ('not', 44033),
#  ('have', 39712),
#  ('were', 39086),
#  ('has', 37866),
#  ('but', 35358),
#  ('other', 32433),
#  ('their', 31523),
#  ('its', 29567),
#  ('first', 28810),
#  ('they', 28553),
#  ('some', 28161),
#  ('had', 28100),
#  ('all', 26229),
#  ('more', 26223),
#  ('most', 25563),
#  ('can', 25519),
#  ('been', 25383),
#  ('such', 24413),
#  ('many', 24096),
#  ('who', 23997),
#  ('new', 23770),
#  ('used', 22737),
#  ('there', 22707),
#  ('after', 21125),
#  ('when', 20623),
#  ('into', 20484),
#  ('american', 20477),
#  ('time', 20412),
#  ('these', 19864),
#  ('only', 19463),
#  ('see', 19206),
#  ('may', 19115),
#  ('than', 18807),
#  ('world', 17949),
#  ('i', 17581),
#  ('b', 17516),
#  ('would', 17377),
#  ('d', 17236),
#  ('no', 16155),
#  ('however', 15861),
#  ('between', 15737),
#  ('about', 15574),
#  ('over', 15122),
#  ('years', 14935),
#  ('states', 14916),
#  ('people', 14696),
#  ('war', 14629),
#  ('during', 14578),
#  ('united', 14494),
#  ('known', 14437),
#  ('if', 14420),
#  ('called', 14151),
#  ('use', 14011),
#  ('th', 13380),
#  ('system', 13296),
#  ('often', 12987),
#  ('state', 12904),
#  ('so', 12722),
#  ('history', 12623),
#  ('will', 12560),
#  ('up', 12445),
#  ('while', 12363),
#  ('where', 12347),
#  ('city', 12275),
#  ('being', 11931),
#  ('english', 11868),
#  ('then', 11847),
#  ('any', 11803),
#  ('both', 11755),
#  ('under', 11753),
#  ('out', 11721),
#  ('made', 11701),
#  ('well', 11537),
#  ('her', 11536),
#  ('e', 11426),
#  ('number', 11399),
#  ('government', 11323),
#  ('them', 11285),
#  ('m', 10976),
#  ('later', 10971),
#  ('since', 10691),
#  ('him', 10629),
#  ('part', 10627),
#  ('name', 10572),
#  ('c', 10561),
#  ('century', 10550),
#  ('through', 10371),
#  ('because', 10332),
#  ('x', 10307),
#  ('university', 10195),
#  ('early', 10172),
#  ('life', 10096),
#  ('british', 10056),
#  ('year', 9858),
#  ('like', 9854),
#  ('same', 9774),
#  ('including', 9633),
#  ('became', 9591),
#  ('example', 9539),
#  ('day', 9534),
#  ('each', 9500),
#  ('even', 9412),
#  ('work', 9388),
#  ('language', 9375),
#  ('although', 9286),
#  ('several', 9168),
#  ('form', 9133),
#  ('john', 8956),
#  ('u', 8928),
#  ('national', 8904),
#  ('very', 8861),
#  ('much', 8822),
#  ('g', 8773),
#  ('french', 8736),
#  ('before', 8700),
#  ('general', 8659),
#  ('what', 8581),
#  ('t', 8491),
#  ('against', 8432),
#  ('n', 8372),
#  ('high', 8337),
#  ('links', 8312),
#  ('could', 8304),
#  ('based', 8244),
#  ('those', 8209),
#  ('now', 8206),
#  ('second', 8110),
#  ('de', 8002),
#  ('music', 7987),
#  ('another', 7933),
#  ('large', 7898),
#  ('she', 7896),
#  ('f', 7878),
#  ('external', 7862),
#  ('german', 7858),
#  ('different', 7797),
#  ('modern', 7790),
#  ('great', 7770),
#  ('do', 7763),
#  ('common', 7698),
#  ('set', 7682),
#  ('list', 7672),
#  ('south', 7628),
#  ('series', 7611),
#  ('major', 7585),
#  ('game', 7553),
#  ('power', 7522),
#  ('long', 7488),
#  ('country', 7481),
#  ('king', 7456),
#  ('law', 7435),
#  ('group', 7417),
#  ('film', 7400),
#  ('still', 7378),
#  ('until', 7368),
#  ('north', 7328),
#  ('international', 7262),
#  ('term', 7219),
#  ('we', 7118),
#  ('end', 7113),
#  ('book', 7110),
#  ('found', 7043),
#  ('own', 7034),
#  ('political', 6970),
#  ('party', 6943),
#  ('order', 6908),
#  ('usually', 6872),
#  ('president', 6865),
#  ('church', 6786),
#  ('you', 6690),
#  ('death', 6684),
#  ('theory', 6604),
#  ('area', 6591),
#  ('around', 6576),
#  ('include', 6531),
#  ('god', 6518),
#  ('ii', 6494),
#  ('way', 6433),
#  ('did', 6419),
#  ('military', 6410),
#  ('population', 6400),
#  ('using', 6384),
#  ('though', 6362),
#  ('small', 6361),
#  ('following', 6300),
#  ('within', 6238),
#  ('non', 6220),
#  ('left', 6184),
#  ('human', 6184),
#  ('main', 6166),
#  ('among', 6146),
#  ('point', 6141),
#  ('r', 6064),
#  ('due', 6056),
#  ('p', 6001),
#  ('considered', 5985),
#  ('public', 5976),
#  ('popular', 5967),
#  ('computer', 5874),
#  ('west', 5862),
#  ('family', 5857),
#  ('east', 5854),
#  ('information', 5844),
#  ('important', 5843),
#  ('european', 5806),
#  ('man', 5778),
#  ('sometimes', 5761),
#  ('right', 5758),
#  ('old', 5711),
#  ('free', 5684),
#  ('word', 5678),
#  ('without', 5661),
#  ('last', 5654),
#  ('us', 5652),
#  ('members', 5634),
#  ('given', 5605),
#  ('times', 5582),
#  ('roman', 5468),
#  ('make', 5450),
#  ('h', 5404),
#  ('age', 5350),
#  ('place', 5345),
#  ('l', 5343),
#  ('thus', 5319),
#  ('science', 5314),
#  ('case', 5289),
#  ('become', 5268),
#  ('systems', 5262),
#  ('union', 5248),
#  ('born', 5246),
#  ('york', 5243),
#  ('line', 5236),
#  ('countries', 5231),
#  ('does', 5221),
#  ('isbn', 5216),
#  ('st', 5207),
#  ('control', 5196),
#  ('various', 5163),
#  ('others', 5160),
#  ('house', 5157),
#  ('article', 5143),
#  ('island', 5124),
#  ('should', 5113),
#  ('led', 5108),
#  ('back', 5105),
#  ('period', 5099),
#  ('player', 5096),
#  ('europe', 5094),
#  ('languages', 5087),
#  ('central', 5070),
#  ('water', 5025),
#  ('few', 5013),
#  ('western', 5010),
#  ('home', 5007),
#  ('began', 5004),
#  ('generally', 4979),
#  ('less', 4974),
#  ('k', 4970),
#  ('similar', 4939),
#  ('written', 4916),
#  ('original', 4910),
#  ('best', 4902),
#  ('must', 4898),
#  ('according', 4884),
#  ('school', 4872),
#  ('france', 4813),
#  ('air', 4802),
#  ('single', 4801),
#  ('force', 4776),
#  ('v', 4762),
#  ('land', 4755),
#  ('groups', 4731),
#  ('down', 4728),
#  ('how', 4727),
#  ('works', 4724),
#  ('development', 4721),
#  ('official', 4720),
#  ('support', 4686),
#  ('england', 4641),
#  ('j', 4612),
#  ('rather', 4605),
#  ('data', 4586),
#  ('space', 4586),
#  ('greek', 4577),
#  ('km', 4574),
#  ('named', 4551),
#  ('germany', 4539),
#  ('just', 4528),
#  ('games', 4527),
#  ('said', 4483),
#  ('version', 4472),
#  ('late', 4471),
#  ('earth', 4457),
#  ('company', 4448),
#  ('every', 4446),
#  ('economic', 4435),
#  ('short', 4433),
#  ('published', 4430),
#  ('black', 4429),
#  ('army', 4418),
#  ('off', 4414),
#  ('london', 4399),
#  ('million', 4386),
#  ('body', 4383),
#  ('field', 4352),
#  ('christian', 4347),
#  ('either', 4330),
#  ('social', 4307),
#  ('empire', 4307),
#  ('o', 4299),
#  ('developed', 4270),
#  ('standard', 4269),
#  ('court', 4268),
#  ('service', 4260),
#  ('kingdom', 4257),
#  ('along', 4241),
#  ('college', 4236),
#  ('republic', 4231),
#  ('sea', 4212),
#  ('america', 4202),
#  ('today', 4198),
#  ('result', 4193),
#  ('held', 4178),
#  ('team', 4176),
#  ('light', 4172),
#  ('means', 4165),
#  ('never', 4127),
#  ('especially', 4125),
#  ('third', 4121),
#  ('further', 4118),
#  ('forces', 4114),
#  ('character', 4114),
#  ('take', 4105),
#  ('men', 4078),
#  ('society', 4067),
#  ('show', 4064),
#  ('open', 4063),
#  ('possible', 4051),
#  ('fact', 4042),
#  ('battle', 4034),
#  ('took', 4013),
#  ('former', 4007),
#  ('books', 3992),
#  ('soviet', 3985),
#  ('river', 3984),
#  ('children', 3978),
#  ('having', 3964),
#  ('good', 3962),
#  ('local', 3960),
#  ('current', 3955),
#  ('son', 3955),
#  ('process', 3949),
#  ('natural', 3947),
#  ('present', 3922),
#  ('himself', 3919),
#  ('islands', 3903),
#  ('total', 3891),
#  ('near', 3874),
#  ('white', 3866),
#  ('days', 3863),
#  ('person', 3855),
#  ('itself', 3843),
#  ('seen', 3831),
#  ('culture', 3809),
#  ('little', 3805),
#  ('above', 3782),
#  ('software', 3773),
#  ('largest', 3772),
#  ('words', 3771),
#  ('upon', 3768),
#  ('level', 3767),
#  ('father', 3762),
#  ('created', 3760),
#  ('side', 3760),
#  ('red', 3755),
#  ('references', 3747),
#  ('press', 3745),
#  ('full', 3734),
#  ('region', 3726),
#  ('almost', 3717),
#  ('al', 3714),
#  ('image', 3714),
#  ('famous', 3708),
#  ('play', 3702),
#  ('came', 3698),
#  ('role', 3691),
#  ('once', 3686),
#  ('certain', 3675),
#  ('league', 3663),
#  ('jewish', 3662),
#  ('james', 3653),
#  ('january', 3650),
#  ('site', 3639),
#  ('again', 3616),
#  ('numbers', 3611),
#  ('art', 3611),
#  ('member', 3601),
#  ('areas', 3599),
#  ('movement', 3595),
#  ('religious', 3588),
#  ('type', 3588),
#  ('march', 3583),
#  ('community', 3581),
#  ('story', 3573),
#  ('played', 3572),
#  ('production', 3570),
#  ('released', 3555),
#  ('center', 3548),
#  ('rights', 3546),
#  ('real', 3545),
#  ('related', 3536),
#  ('foreign', 3528),
#  ('low', 3524),
#  ('ancient', 3523),
#  ('terms', 3519),
#  ('view', 3519),
#  ('source', 3503),
#  ('act', 3502),
#  ('minister', 3493),
#  ('change', 3483),
#  ('energy', 3464),
#  ('produced', 3457),
#  ('research', 3452),
#  ('actor', 3451),
#  ('making', 3448),
#  ('december', 3443),
#  ('civil', 3443),
#  ('women', 3442),
#  ('special', 3441),
#  ('style', 3438),
#  ('japanese', 3437),
#  ('design', 3437),
#  ('william', 3437),
#  ('available', 3435),
#  ('chinese', 3430),
#  ('forms', 3429),
#  ('canada', 3428),
#  ('northern', 3423),
#  ('died', 3418),
#  ('class', 3412),
#  ('living', 3410),
#  ('next', 3406),
#  ('particular', 3404),
#  ('program', 3403),
#  ('council', 3401),
#  ('television', 3395),
#  ('head', 3376),
#  ('david', 3368),
#  ('china', 3365),
#  ('middle', 3363),
#  ('established', 3360),
#  ('hand', 3356),
#  ('bc', 3356),
#  ('far', 3352),
#  ('july', 3333),
#  ('function', 3330),
#  ('position', 3318),
#  ('y', 3311),
#  ('built', 3310),
#  ('george', 3307),
#  ('band', 3304),
#  ('together', 3303),
#  ('w', 3301),
#  ('latin', 3290),
#  ('thought', 3277),
#  ('eastern', 3276),
#  ('charles', 3268),
#  ('parts', 3266),
#  ('instead', 3259),
#  ('study', 3248),
#  ('india', 3242),
#  ('might', 3242),
#  ('code', 3240),
#  ('meaning', 3213),
#  ('included', 3213),
#  ('trade', 3207),
#  ('per', 3206),
#  ('june', 3195),
#  ('least', 3185),
#  ('half', 3176),
#  ('model', 3141),
#  ('economy', 3136),
#  ('prime', 3135),
#  ('traditional', 3133),
#  ('always', 3131),
#  ('capital', 3129),
#  ('range', 3125),
#  ('emperor', 3119),
#  ('november', 3119),
#  ('young', 3109),
#  ('anti', 3103),
#  ('final', 3102),
#  ('text', 3098),
#  ('players', 3088),
#  ('uk', 3079),
#  ('april', 3069),
#  ('run', 3063),
#  ('september', 3055),
#  ('addition', 3050),
#  ('radio', 3050),
#  ('live', 3046),
#  ('august', 3044),
#  ('note', 3043),
#  ('taken', 3043),
#  ('italian', 3037),
#  ('lost', 3035),
#  ('nature', 3027),
#  ('project', 3022),
#  ('technology', 3017),
#  ('spanish', 3011),
#  ('october', 3009),
#  ('rate', 3002),
#  ('recent', 3002),
#  ('won', 2989),
#  ('true', 2965),
#  ('value', 2964),
#  ('uses', 2963),
#  ('russian', 2961),
#  ('est', 2959),
#  ('wrote', 2935),
#  ('effect', 2933),
#  ('album', 2932),
#  ('southern', 2927),
#  ('africa', 2923),
#  ('whose', 2914),
#  ('top', 2913),
#  ('historical', 2899),
#  ('australia', 2895),
#  ('catholic', 2888),
#  ('particularly', 2882),
#  ('self', 2879),
#  ('structure', 2876),
#  ('record', 2863),
#  ('evidence', 2857),
#  ('rule', 2852),
#  ('themselves', 2852),
#  ('influence', 2845),
#  ('cases', 2843),
#  ('subject', 2830),
#  ('referred', 2829),
#  ('continued', 2822),
#  ('nations', 2821),
#  ('rock', 2819),
#  ('below', 2819),
#  ('japan', 2817),
#  ('com', 2810),
#  ('song', 2809),
#  ('throughout', 2806),
#  ('names', 2806),
#  ('female', 2797),
#  ('title', 2796),
#  ('therefore', 2795),
#  ('our', 2795),
#  ('office', 2785),
#  ('star', 2784),
#  ('paul', 2777),
#  ('too', 2775),
#  ('cities', 2773),
#  ('independent', 2771),
#  ('february', 2771),
#  ('author', 2769),
#  ('problem', 2767),
#  ('species', 2761),
#  ('done', 2759),
#  ('education', 2759),
#  ('philosophy', 2758),
#  ('come', 2755),
#  ('higher', 2753),
#  ('originally', 2752),
#  ('market', 2748),
#  ('town', 2746),
#  ('my', 2745),
#  ('season', 2741),
#  ('love', 2740),
#  ('strong', 2736),
#  ('israel', 2735),
#  ('irish', 2731),
#  ('writer', 2731),
#  ('films', 2727),
#  ('elements', 2723),
#  ('robert', 2722),
#  ('whether', 2719),
#  ('despite', 2716),
#  ('eventually', 2714),
#  ('here', 2709),
#  ('football', 2708),
#  ('action', 2699),
#  ('internet', 2697),
#  ('individual', 2693),
#  ('sound', 2693),
#  ('network', 2691),
#  ('described', 2685),
#  ('practice', 2681),
#  ('characters', 2674),
#  ('re', 2664),
#  ('royal', 2663),
#  ('la', 2660),
#  ('events', 2650),
#  ('formed', 2644),
#  ('commonly', 2638),
#  ('base', 2633),
#  ('received', 2632),
#  ('problems', 2628),
#  ('african', 2628),
#  ('food', 2623),
#  ('jews', 2620),
#  ('able', 2619),
#  ('male', 2615),
#  ('typically', 2595),
#  ('mass', 2595),
#  ('complex', 2593),
#  ('lower', 2583),
#  ('includes', 2576),
#  ('outside', 2574),
#  ('legal', 2562),
#  ('complete', 2561),
#  ('parliament', 2554),
#  ('significant', 2554),
#  ('actually', 2553),
#  ('business', 2542),
#  ('fiction', 2540),
#  ('physical', 2539),
#  ('followed', 2537),
#  ('deaths', 2530),
#  ('key', 2527),
#  ('widely', 2525),
#  ('leader', 2525),
#  ('page', 2520),
#  ('basic', 2519),
#  ('types', 2518),
#  ('henry', 2494),
#  ('elected', 2493),
#  ('beginning', 2493),
#  ('fire', 2489),
#  ('building', 2480),
#  ('independence', 2478),
#  ('went', 2475),
#  ('aircraft', 2471),
#  ('movie', 2471),
#  ('ever', 2470),
#  ('canadian', 2468),
#  ('material', 2464),
#  ('births', 2462),
#  ('video', 2461),
#  ('news', 2458),
#  ('future', 2457),
#  ('scientific', 2456),
#  ('simply', 2454),
#  ('go', 2451),
#  ('defined', 2449),
#  ('laws', 2444),
#  ('get', 2440),
#  ('close', 2439),
#  ('industry', 2434),
#  ('specific', 2432),
#  ('examples', 2431),
#  ('services', 2404),
#  ('believe', 2404),
#  ('idea', 2398),
#  ('introduced', 2397),
#  ('method', 2397),
#  ('points', 2396),
#  ('return', 2395),
#  ('cause', 2392),
#  ('indian', 2389),
#  ('britain', 2384),
#  ('features', 2380),
#  ('majority', 2379),
#  ('size', 2379),
#  ('post', 2376),
#  ('lead', 2375),
#  ('organization', 2374),
#  ('cannot', 2373),
#  ('designed', 2364),
#  ('ireland', 2362),
#  ('cross', 2361),
#  ('classical', 2359),
#  ('personal', 2357),
#  ('writing', 2356),
#  ('concept', 2353),
#  ('required', 2349),
#  ('associated', 2349),
#  ('soon', 2343),
#  ('changes', 2337),
#  ('located', 2336),
#  ('california', 2336),
#  ('sense', 2331),
#  ('believed', 2319),
#  ('started', 2313),
#  ('away', 2313),
#  ('co', 2308),
#  ('religion', 2304),
#  ('mother', 2303),
#  ('county', 2300),
#  ('rules', 2299),
#  ('studies', 2298),
#  ('yet', 2296),
#  ('find', 2290),
#  ('knowledge', 2289),
#  ('put', 2288),
#  ('founded', 2282),
#  ('policy', 2278),
#  ('currently', 2275),
#  ('provide', 2272),
#  ('working', 2271),
#  ('media', 2267),
#  ('election', 2266),
#  ('australian', 2260),
#  ('me', 2256),
#  ('thomas', 2255),
#  ('allowed', 2252),
#  ('russia', 2251),
#  ('greater', 2249),
#  ('earlier', 2249),
#  ('limited', 2248),
#  ('object', 2243),
#  ('brought', 2241),
#  ('online', 2236),
#  ('association', 2231),
#  ('lord', 2231),
#  ('mostly', 2227),
#  ('blue', 2223),
#  ('across', 2222),
#  ('constitution', 2222),
#  ('added', 2218),
#  ('interest', 2217),
#  ('things', 2216),
#  ('relations', 2215),
#  ('speed', 2206),
#  ('federal', 2200),
#  ('singer', 2195),
#  ('effects', 2194),
#  ('growth', 2193),
#  ('sources', 2192),
#  ('your', 2189),
#  ('remains', 2183),
#  ('z', 2182),
#  ('gave', 2178),
#  ('probably', 2178),
#  ('simple', 2177),
#  ('attack', 2175),
#  ('longer', 2174),
#  ('reference', 2171),
#  ('saint', 2168),
#  ('success', 2164),
#  ('killed', 2163),
#  ('past', 2162),
#  ('career', 2162),
#  ('need', 2159),
#  ('park', 2156),
#  ('definition', 2147),
#  ('say', 2139),
#  ('etc', 2137),
#  ('give', 2133),
#  ('peace', 2133),
#  ('chief', 2130),
#  ('stories', 2128),
#  ('security', 2126),
#  ('wide', 2125),
#  ('ball', 2124),
#  ('saw', 2119),
#  ('machine', 2117),
#  ('better', 2116),
#  ('cell', 2115),
#  ('leading', 2114),
#  ('becomes', 2111),
#  ('spain', 2109),
#  ('larger', 2109),
#  ('night', 2108),
#  ('products', 2108),
#  ('parties', 2108),
#  ('remained', 2105),
#  ('prize', 2103),
#  ('website', 2102),
#  ('months', 2102),
#  ('big', 2102),
#  ('cultural', 2101),
#  ('money', 2101),
#  ('help', 2099),
#  ('territory', 2099),
#  ('private', 2098),
#  ('moved', 2098),
#  ('wife', 2093),
#  ('letter', 2093),
#  ('politics', 2090),
#  ('lines', 2090),
#  ('largely', 2089),
#  ('contains', 2086),
#  ('companies', 2084),
#  ('lake', 2080),
#  ('perhaps', 2079),
#  ('green', 2074),
#  ('already', 2070),
#  ('iii', 2069),
#  ('dead', 2069),
#  ('library', 2068),
#  ('separate', 2067),
#  ('refer', 2066),
#  ('makes', 2065),
#  ('appeared', 2064),
#  ('dutch', 2060),
#  ('holy', 2059),
#  ('era', 2057),
#  ('novel', 2054),
#  ('successful', 2052),
#  ('italy', 2050),
#  ('letters', 2049),
#  ('results', 2048),
#  ('matter', 2045),
#  ('produce', 2042),
#  ('origin', 2041),
#  ('claim', 2039),
#  ('whole', 2034),
#  ('directly', 2033),
#  ('attempt', 2033),
#  ('actress', 2031),
#  ('surface', 2030),
#  ('revolution', 2029),
#  ('highly', 2026),
#  ('caused', 2025),
#  ('status', 2024),
#  ('musical', 2022),
#  ('richard', 2021),
#  ('commercial', 2020),
#  ('division', 2018),
#  ('color', 2017),
#  ('release', 2013),
#  ('health', 2013),
#  ('coast', 2013),
#  ('latter', 2012),
#  ('authority', 2009),
#  ('treaty', 2007),
#  ('turn', 2005),
#  ('michael', 2000),
#  ('nation', 1995),
#  ('direct', 1994),
#  ('asia', 1992),
#  ('edition', 1990),
#  ('programming', 1989),
#  ('playing', 1981),
#  ('date', 1980),
#  ('whom', 1977),
#  ('mary', 1977),
#  ('native', 1977),
#  ('married', 1973),
#  ('towards', 1971),
#  ('issues', 1967),
#  ('double', 1966),
#  ('primary', 1959),
#  ('basis', 1959),
#  ('enough', 1958),
#  ('allow', 1958),
#  ('memory', 1957),
#  ('reason', 1954),
#  ('web', 1952),
#  ('exist', 1950),
#  ('provided', 1948),
#  ('functions', 1945),
#  ('course', 1945),
#  ('oil', 1945),
#  ('alexander', 1944),
#  ('analysis', 1944),
#  ('chemical', 1944),
#  ('mid', 1941),
#  ('replaced', 1941),
#  ('queen', 1940),
#  ('tv', 1938),
#  ('sun', 1938),
#  ('claims', 1938),
#  ('literature', 1936),
#  ('metal', 1935),
#  ('amount', 1934),
#  ('divided', 1930),
#  ('blood', 1927),
#  ('likely', 1926),
#  ('access', 1924),
#  ('average', 1924),
#  ('length', 1922),
#  ('smaller', 1921),
#  ('medical', 1919),
#  ('property', 1918),
#  ('students', 1916),
#  ('degree', 1915),
#  ('elections', 1914),
#  ('club', 1913),
#  ('claimed', 1912),
#  ('performance', 1911),
#  ('director', 1907),
#  ('digital', 1905),
#  ('front', 1904),
#  ('museum', 1904),
#  ('tradition', 1903),
#  ('difficult', 1903),
#  ('nearly', 1902),
#  ('schools', 1900),
#  ('washington', 1899),
#  ('gas', 1897),
#  ('jesus', 1896),
#  ('map', 1896),
#  ('louis', 1895),
#  ('rome', 1895),
#  ('unit', 1892),
#  ('baseball', 1890),
#  ('mind', 1888),
#  ('mark', 1887),
#  ('peter', 1887),
#  ('collection', 1883),
#  ('product', 1881),
#  ('congress', 1880),
#  ('programs', 1872),
#  ('changed', 1871),
#  ('ideas', 1870),
#  ('moon', 1868),
#  ('entire', 1866),
#  ('user', 1865),
#  ('ground', 1864),
#  ('records', 1862),
#  ('frequently', 1861),
#  ('increase', 1860),
#  ('highest', 1859),
#  ('finally', 1858),
#  ('sent', 1858),
#  ('board', 1857),
#  ('don', 1856),
#  ('notable', 1854),
#  ('read', 1852),
#  ('methods', 1852),
#  ('recently', 1851),
#  ('bit', 1849),
#  ('variety', 1843),
#  ('involved', 1843),
#  ('call', 1842),
#  ('democratic', 1841),
#  ('ten', 1840),
#  ('served', 1836),
#  ('minor', 1830),
#  ('hard', 1828),
#  ('objects', 1823),
#  ('birth', 1823),
#  ('increased', 1819),
#  ('nuclear', 1819),
#  ('section', 1813),
#  ('street', 1812),
#  ('windows', 1811),
#  ('relatively', 1810),
#  ('car', 1809),
#  ('move', 1808),
#  ('create', 1807),
#  ('returned', 1807),
#  ('bank', 1806),
#  ('conditions', 1805),
#  ('operation', 1802),
#  ('relationship', 1801),
#  ('adopted', 1801),
#  ('christ', 1800),
#  ('hall', 1797),
#  ('appear', 1794),
#  ('rest', 1790),
#  ('child', 1789),
#  ('element', 1787),
#  ('appears', 1786),
#  ('takes', 1783),
#  ...]

# %%
dictionary = dict()
for word, _ in count:                        
    dictionary[word] = len(dictionary)
dictionary['the']
# Out:
# 1

# %%
# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000


def build_dataset(words, n_words):
  """Process raw inputs into a dataset."""
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(n_words - 1))
  dictionary = dict()
  for word, _ in count:                         #每一个单词给一个位置,dictionary['the']=1
    dictionary[word] = len(dictionary)          #其目的就是为了快速的查找
  data = list()
  unk_count = 0
  for word in words:                           #每个单词有一个编号
    if word in dictionary:                     #如果在字典中
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count += 1
    data.append(index)      #编码,对文本数据的编码
  count[0][1] = unk_count   
  reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reversed_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,
                                                            vocabulary_size)
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
dictionary['anarchism']
reverse_dictionary[5239]
# Out:
# 'anarchism'

# %%
# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [skip_window]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index + len(data) - span) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3084 originated -> 5239 anarchism
# 3084 originated -> 12 as
# 12 as -> 3084 originated
# 12 as -> 6 a
# 6 a -> 12 as
# 6 a -> 195 term
# 195 term -> 2 of
# 195 term -> 6 a

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64    # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

  # Construct the SGD optimizer using a learning rate of 1.0.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Add variable initializer.
  init = tf.global_variables_initializer()

# %%
# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # We must initialize all variables before we use them.
  init.run()
  print('Initialized')

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step ', step, ': ', average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = '%s %s,' % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  264.880981445
# Nearest to who: dump, pledging, historian, withdrawing, scanner, scsi, letter, manors,
# Nearest to that: excerpts, stiffer, erm, waterman, pensacola, shallow, toxicity, temmu,
# Nearest to UNK: neutralized, stationary, scorn, globalisation, apocalyptic, soared, pressure, alaskan,
# Nearest to states: introduction, bystander, lehi, offences, browning, paces, klang, sahih,
# Nearest to these: promoting, oliveira, dora, halfdan, ridiculed, specie, multiplicity, akihito,
# Nearest to history: inflatable, chordata, shevat, acs, endo, agnes, dvb, amperes,
# Nearest to called: disproven, tera, demoness, relegation, axumite, depended, sportsman, variadic,
# Nearest to when: techno, darkly, vitally, correctness, contrast, bolshevism, minicomputers, primaries,
# Nearest to of: reductionist, seif, cours, specifier, langmuir, mellor, cve, arnaud,
# Nearest to eight: gutierrez, gearing, arising, spaghetti, awakens, wait, rightist, praxis,
# Nearest to up: narrowest, colored, arrests, wyndham, byrd, occam, shabda, equinoctial,
# Nearest to american: ginger, closer, ductus, block, mingle, turbulent, trek, welcome,
# Nearest to or: nugget, hulk, chieftains, infect, fist, amazonian, declension, baronet,
# Nearest to this: park, bletchley, latency, subkey, hologram, three, ebenezer, unwillingly,
# Nearest to often: lys, richman, copts, chinatown, decomposes, fide, extraordinary, fisherman,
# Nearest to such: promontory, intends, byzantines, overpowered, bowser, palatal, affections, rothschild,
# Average loss at step  2000 :  114.061503729
# Average loss at step  4000 :  52.6113389108
# Average loss at step  6000 :  33.2740646591
# Average loss at step  8000 :  23.6842296462
# Average loss at step  10000 :  17.5182910424
# Nearest to who: dump, basins, and, rubber, vs, ambrose, not, historian,
# Nearest to that: toxicity, oxidation, gauge, and, animation, harder, alpina, grande,
# Nearest to UNK: and, archie, one, the, phi, agave, six, zero,
# Nearest to states: introduction, gland, vs, necessary, bckgr, austin, stay, similar,
# Nearest to these: promoting, unicode, compromises, effects, ridiculed, advocacy, alpina, meditative,
# Nearest to history: socialism, vs, salts, attached, reginae, west, bay, sigma,
# Nearest to called: curtius, alternate, antimatter, patroclus, hermann, lymphoma, allowed, monks,
# Nearest to when: contrast, ambrose, mya, techno, stranger, intent, if, ottoman,
# Nearest to of: in, and, for, unix, the, on, receiving, legendary,
# Nearest to eight: nine, zero, agave, six, mosque, archie, psi, bckgr,
# Nearest to up: colored, contributed, archie, pdf, recognizes, learn, ceres, occam,
# Nearest to american: romans, ch, saul, closer, dynasty, mixes, agave, q,
# Nearest to or: and, lymphoma, voltage, vs, archie, agave, incidents, wasp,
# Nearest to this: park, a, portals, the, neurons, which, it, incorporated,
# Nearest to often: lymphoma, may, sender, fide, vs, unfinished, murchison, called,
# Nearest to such: well, sometimes, prepared, mixture, established, recycling, asteroid, roy,
# Average loss at step  12000 :  14.0549136177
# Average loss at step  14000 :  11.7590365949
# Average loss at step  16000 :  9.84421488535
# Average loss at step  18000 :  8.44334421968
# Average loss at step  20000 :  8.03931596768
# Nearest to who: and, not, operatorname, he, rubber, dump, protestants, foretold,
# Nearest to that: which, this, gauge, and, toxicity, oxidation, operatorname, acacia,
# Nearest to UNK: agouti, operatorname, dasyprocta, agave, circ, archie, three, two,
# Nearest to states: introduction, gland, vs, necessary, dye, acacia, dasyprocta, circ,
# Nearest to these: promoting, the, this, their, operatorname, ridiculed, advocacy, that,
# Nearest to history: socialism, salts, circ, operatorname, attached, agnes, dasyprocta, hawaii,
# Nearest to called: friars, curtius, operatorname, alternate, circ, agouti, aslan, patroclus,
# Nearest to when: if, contrast, ambrose, was, forehead, and, mya, ottoman,
# Nearest to of: in, and, for, dasyprocta, nine, at, on, eight,
# Nearest to eight: nine, zero, six, three, four, dasyprocta, seven, five,
# Nearest to up: colored, contributed, ceres, pdf, occam, temples, recognizes, secrets,
# Nearest to american: and, circ, agouti, dynasty, saul, romans, agave, turbulent,
# Nearest to or: and, UNK, the, eight, agouti, seven, meridians, vs,
# Nearest to this: the, it, which, a, prop, subkey, that, park,
# Nearest to often: lymphoma, wattle, sender, fide, statically, leonid, operatorname, may,
# Nearest to such: well, intends, prepared, established, laser, recycling, sometimes, mixture,
# Average loss at step  22000 :  6.93372301483
# Average loss at step  24000 :  6.91306937146
# Average loss at step  26000 :  6.75893881309
# Average loss at step  28000 :  6.42299632001
# Average loss at step  30000 :  5.93715938771
# Nearest to who: and, he, not, also, operatorname, it, rubber, foretold,
# Nearest to that: which, this, gauge, but, toxicity, operatorname, kokomo, respects,
# Nearest to UNK: agouti, operatorname, dasyprocta, archie, two, six, circ, primigenius,
# Nearest to states: introduction, primigenius, gland, necessary, dye, offences, acacia, vs,
# Nearest to these: their, operatorname, many, promoting, the, which, dek, malagasy,
# Nearest to history: salts, operatorname, socialism, circ, hawaii, attached, dasyprocta, agnes,
# Nearest to called: aba, curtius, friars, operatorname, alternate, circ, agouti, patroclus,
# Nearest to when: if, was, and, after, ottoman, ambrose, contrast, forehead,
# Nearest to of: in, and, for, on, abet, eight, legendary, dasyprocta,
# Nearest to eight: nine, six, seven, four, five, zero, dasyprocta, three,
# Nearest to up: colored, contributed, ceres, pdf, narrowest, occam, secrets, barnabas,
# Nearest to american: and, french, one, circ, dynasty, reuptake, agouti, closer,
# Nearest to or: and, operatorname, seven, agouti, six, meridians, abet, eight,
# Nearest to this: which, it, the, a, prop, that, any, subkey,
# Nearest to often: lymphoma, sender, wattle, sponsors, fide, statically, leonid, kokomo,
# Nearest to such: well, intends, laser, wideawake, prepared, asteroid, established, sometimes,
# Average loss at step  32000 :  5.96021679664
# Average loss at step  34000 :  5.70483196878
# Average loss at step  36000 :  5.76977608287
# Average loss at step  38000 :  5.47838031232
# Average loss at step  40000 :  5.27645704663
# Nearest to who: he, and, also, not, operatorname, dump, which, it,
# Nearest to that: which, this, but, it, what, operatorname, four, toxicity,
# Nearest to UNK: agouti, dasyprocta, four, operatorname, three, circ, abet, seven,
# Nearest to states: primigenius, introduction, gland, necessary, dye, kingdom, offences, circ,
# Nearest to these: many, some, their, operatorname, which, other, promoting, such,
# Nearest to history: hawaii, circ, operatorname, salts, socialism, west, dasyprocta, attached,
# Nearest to called: and, aba, UNK, curtius, friars, operatorname, agouti, considered,
# Nearest to when: if, in, after, was, ambrose, as, ottoman, forehead,
# Nearest to of: in, abet, dasyprocta, for, zero, and, eight, legendary,
# Nearest to eight: six, nine, seven, four, five, zero, three, dasyprocta,
# Nearest to up: ceres, colored, contributed, pdf, occam, arrests, narrowest, secrets,
# Nearest to american: and, french, circ, agouti, ece, dynasty, closer, turbulent,
# Nearest to or: and, abet, agouti, operatorname, meridians, eight, vs, truetype,
# Nearest to this: which, it, that, the, prop, a, one, portals,
# Nearest to often: lymphoma, sometimes, wattle, sender, now, curtail, then, statically,
# Nearest to such: well, gro, intends, these, wideawake, laser, dirty, notable,
# Average loss at step  42000 :  5.35841706765
# Average loss at step  44000 :  5.25481397915
# Average loss at step  46000 :  5.20204149842
# Average loss at step  48000 :  5.21908290601
# Average loss at step  50000 :  4.97604093671
# Nearest to who: he, and, also, operatorname, not, which, dump, they,
# Nearest to that: which, this, but, what, kapoor, it, operatorname, acacia,
# Nearest to UNK: agouti, dasyprocta, operatorname, phi, four, kapoor, circ, archie,
# Nearest to states: introduction, primigenius, phospholipids, kingdom, gland, expecting, dye, necessary,
# Nearest to these: many, some, their, operatorname, such, which, other, several,
# Nearest to history: hawaii, operatorname, circ, salts, socialism, agnes, dasyprocta, ammonites,
# Nearest to called: and, aba, considered, operatorname, agouti, friars, curtius, circ,
# Nearest to when: if, and, after, as, while, was, in, ambrose,
# Nearest to of: in, abet, dasyprocta, for, kapoor, nine, agouti, eight,
# Nearest to eight: six, seven, nine, four, five, three, dasyprocta, zero,
# Nearest to up: contributed, ceres, colored, wyndham, arrests, occam, suggest, secrets,
# Nearest to american: french, and, circ, agouti, ece, five, enfant, bentham,
# Nearest to or: and, eight, seven, four, six, agouti, abet, five,
# Nearest to this: which, it, the, that, a, portals, prop, kapoor,
# Nearest to often: sometimes, lymphoma, now, wattle, then, it, sender, operatorname,
# Nearest to such: well, these, gro, intends, notable, wideawake, laser, dirty,
# Average loss at step  52000 :  5.05283641994
# Average loss at step  54000 :  5.18943756163
# Average loss at step  56000 :  5.03434960711
# Average loss at step  58000 :  5.03006289589
# Average loss at step  60000 :  4.92516904855
# Nearest to who: he, which, also, operatorname, it, they, not, there,
# Nearest to that: which, this, ursus, but, what, wct, it, kapoor,
# Nearest to UNK: agouti, ursus, dasyprocta, operatorname, wct, circ, kapoor, three,
# Nearest to states: ursus, michelob, primigenius, expecting, kingdom, gland, phospholipids, dye,
# Nearest to these: many, some, ursus, such, their, other, several, two,
# Nearest to history: hawaii, pulau, operatorname, circ, ursus, dek, salts, dasyprocta,
# Nearest to called: and, aba, UNK, considered, operatorname, friars, curtius, agouti,
# Nearest to when: if, after, while, as, before, was, six, ursus,
# Nearest to of: in, nine, abet, wct, and, ursus, dasyprocta, legendary,
# Nearest to eight: nine, six, seven, five, four, zero, three, dasyprocta,
# Nearest to up: contributed, ceres, them, suggest, occam, arrests, colored, wyndham,
# Nearest to american: and, french, ece, german, circ, agouti, enfant, ursus,
# Nearest to or: and, ursus, agouti, abet, operatorname, meridians, wct, truetype,
# Nearest to this: which, it, that, the, ursus, one, kapoor, agouti,
# Nearest to often: sometimes, now, it, lymphoma, then, wattle, generally, also,
# Nearest to such: well, these, gro, intends, notable, laser, many, wideawake,
# Average loss at step  62000 :  5.00297946715
# Average loss at step  64000 :  4.82606683934
# Average loss at step  66000 :  4.5867054683
# Average loss at step  68000 :  4.98207311523
# Average loss at step  70000 :  4.88857615328
# Nearest to who: he, which, not, operatorname, also, they, and, it,
# Nearest to that: which, this, but, ursus, what, kapoor, wct, microcebus,
# Nearest to UNK: microcebus, agouti, ursus, mitral, operatorname, dasyprocta, wct, circ,
# Nearest to states: mitral, cebus, ursus, kingdom, expecting, phospholipids, michelob, gland,
# Nearest to these: many, some, such, ursus, their, several, which, other,
# Nearest to history: operatorname, hawaii, pulau, ursus, dek, acceptance, circ, dasyprocta,
# Nearest to called: and, aba, considered, operatorname, UNK, agouti, friars, forsyth,
# Nearest to when: if, after, while, before, as, microcebus, in, since,
# Nearest to of: abet, wct, ursus, kapoor, legendary, and, dasyprocta, thaler,
# Nearest to eight: six, seven, nine, five, four, zero, three, dasyprocta,
# Nearest to up: them, contributed, cebus, ceres, wyndham, sylia, arrests, occam,
# Nearest to american: french, and, ece, german, bentham, circ, dido, enfant,
# Nearest to or: and, microcebus, ursus, abet, agouti, dasyprocta, operatorname, truetype,
# Nearest to this: which, it, the, that, ursus, microcebus, agouti, kapoor,
# Nearest to often: sometimes, now, generally, then, also, lymphoma, usually, wattle,
# Nearest to such: well, these, gro, intends, notable, many, shek, microcebus,
# Average loss at step  72000 :  4.73433390665
# Average loss at step  74000 :  4.80846013856
# Average loss at step  76000 :  4.71990174365
# Average loss at step  78000 :  4.79291702542
# Average loss at step  80000 :  4.79257811618
# Nearest to who: he, they, which, also, operatorname, not, there, dump,
# Nearest to that: which, this, but, ursus, what, kapoor, it, microcebus,
# Nearest to UNK: agouti, microcebus, ursus, dasyprocta, cebus, operatorname, circ, busan,
# Nearest to states: kingdom, mitral, cebus, expecting, ursus, phospholipids, michelob, gland,
# Nearest to these: many, some, such, ursus, which, their, several, all,
# Nearest to history: hawaii, acceptance, dek, pulau, operatorname, ursus, circ, dasyprocta,
# Nearest to called: considered, aba, and, operatorname, friars, agouti, UNK, sportsman,
# Nearest to when: if, after, while, before, as, microcebus, was, busan,
# Nearest to of: in, abet, ursus, dasyprocta, wct, kapoor, nine, mitral,
# Nearest to eight: nine, six, seven, five, four, dasyprocta, zero, three,
# Nearest to up: them, cebus, wyndham, contributed, busan, arrests, ossie, sylia,
# Nearest to american: french, ece, german, and, dido, bentham, circ, british,
# Nearest to or: and, microcebus, busan, abet, ursus, operatorname, dasyprocta, agouti,
# Nearest to this: which, it, that, the, ursus, some, dasyprocta, agouti,
# Nearest to often: sometimes, now, generally, usually, also, commonly, lymphoma, then,
# Nearest to such: well, these, gro, many, intends, notable, shek, some,
# Average loss at step  82000 :  4.75790347958
# Average loss at step  84000 :  4.7559382447
# Average loss at step  86000 :  4.7696173923
# Average loss at step  88000 :  4.75024527419
# Average loss at step  90000 :  4.71857820499
# Nearest to who: he, they, which, and, operatorname, not, there, also,
# Nearest to that: which, but, this, ursus, however, what, kapoor, wct,
# Nearest to UNK: agouti, dasyprocta, ursus, operatorname, microcebus, thaler, circ, busan,
# Nearest to states: kingdom, expecting, mitral, cebus, phospholipids, ursus, michelob, primigenius,
# Nearest to these: many, some, such, which, ursus, several, their, operatorname,
# Nearest to history: hawaii, acceptance, pulau, dek, operatorname, ursus, circ, dasyprocta,
# Nearest to called: considered, aba, and, operatorname, UNK, agouti, friars, sportsman,
# Nearest to when: if, after, while, before, as, was, although, since,
# Nearest to of: wct, abet, ursus, in, thaler, dasyprocta, escuela, including,
# Nearest to eight: seven, nine, six, five, four, three, dasyprocta, zero,
# Nearest to up: them, wyndham, cebus, arrests, busan, contributed, ossie, transduction,
# Nearest to american: french, german, british, ece, bentham, and, english, circ,
# Nearest to or: and, microcebus, busan, abet, ursus, agouti, dasyprocta, mosque,
# Nearest to this: which, it, the, that, ursus, a, itself, one,
# Nearest to often: sometimes, now, generally, usually, commonly, also, not, there,
# Nearest to such: well, these, gro, many, some, notable, intends, shek,
# Average loss at step  92000 :  4.65971029174
# Average loss at step  94000 :  4.71892665899
# Average loss at step  96000 :  4.68330739033
# Average loss at step  98000 :  4.59717704588
# Average loss at step  100000 :  4.70583933258
# Nearest to who: he, they, also, operatorname, which, not, and, pulau,
# Nearest to that: which, but, this, what, ursus, however, kapoor, wct,
# Nearest to UNK: agouti, microcebus, ursus, operatorname, mitral, cebus, wct, dasyprocta,
# Nearest to states: kingdom, expecting, mitral, ursus, cebus, phospholipids, michelob, primigenius,
# Nearest to these: many, some, such, several, ursus, which, their, all,
# Nearest to history: endo, hawaii, dek, pulau, acceptance, ursus, operatorname, circ,
# Nearest to called: considered, aba, operatorname, friars, sportsman, and, agouti, forsyth,
# Nearest to when: if, while, after, before, although, since, during, as,
# Nearest to of: wct, abet, ursus, in, escuela, dasyprocta, mitral, eight,
# Nearest to eight: seven, five, nine, six, four, zero, three, dasyprocta,
# Nearest to up: them, wyndham, breakbeats, cebus, busan, arrests, contributed, transduction,
# Nearest to american: french, and, british, german, circ, bentham, ece, dido,
# Nearest to or: and, microcebus, abet, ursus, busan, dasyprocta, agouti, four,
# Nearest to this: which, it, the, that, itself, some, ursus, kapoor,
# Nearest to often: sometimes, now, generally, usually, commonly, also, typically, there,
# Nearest to such: well, these, many, gro, known, some, including, notable,

# %%
# Step 6: Visualize the embeddings.
def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
  assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)

try:
  # pylint: disable=g-import-not-at-top
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
  plot_only = 500
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels)

except ImportError:
    print('Please install sklearn, matplotlib, and scipy to show embeddings.')
